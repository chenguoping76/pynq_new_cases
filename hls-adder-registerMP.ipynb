# %% [markdown]
# # demo pynq driver a IP generated form HLS tool

# %% [markdown]
# ![1734834729085.png](attachment:a4b84ce8-d0c3-4397-aa12-a9656b7edd28.png)

# %%
from pynq import Overlay

# %%
ol = Overlay('./overlay/hls-adder.bit')

# %%
#ol.ip_dict

# %%
hls_adder = ol.adder_ip_0

# %%
hls_adder.register_map
# Out:
# RegisterMap {
#   CTRL = Register(AP_START=0, AP_DONE=0, AP_IDLE=1, AP_READY=0, RESERVED_1=0, AUTO_RESTART=0, RESERVED_2=0, INTERRUPT=0, RESERVED_3=0),
#   GIER = Register(Enable=0, RESERVED=0),
#   IP_IER = Register(CHAN0_INT_EN=0, CHAN1_INT_EN=0, RESERVED_0=0),
#   IP_ISR = Register(CHAN0_INT_ST=0, CHAN1_INT_ST=0, RESERVED_0=0),
#   out_r = Register(out_r=0),
#   out_r_ctrl = Register(out_r_ap_vld=0, RESERVED=0),
#   a = Register(a=write-only),
#   b = Register(b=write-only)
# }

# %%
hls_adder.register_map.a = 3
hls_adder.register_map.b = 2

# %%
hls_adder.register_map.CTRL.AP_START = 1

# %%
hls_adder.register_map.out_r
# Out:
# Register(out_r=5)
